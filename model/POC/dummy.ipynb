# %%
import os
import pandas as pd

load_dir = r"C:\Users\olish\Documents\ml_projects\Steps_Predictor\model\data\clean\steps"

dfs = {}

for file_name in os.listdir(load_dir):
    if file_name.endswith(".pkl"):
        file_path = os.path.join(load_dir, file_name)
        
        df_name = file_name.replace(".pkl", "")
        dfs[df_name] = pd.read_pickle(file_path)

# %%
df = dfs['oli']

# %%
df.head(30)
# Out:
#          date  value day
# 0  2018-11-18   4390  18
# 1  2018-11-19   8335  19
# 2  2018-11-20   6946  20
# 3  2018-11-21   8350  21
# 4  2018-11-22  11054  22
# 5  2018-11-23  10374  23
# 6  2018-11-24   8146  24
# 7  2018-11-25   8627  25
# 8  2018-11-26   7909  26
# 9  2018-11-27   4124  27
# 10 2018-11-28  12391  28
# 11 2018-11-29   7212  29
# 12 2018-11-30   6379  30
# 13 2018-12-01   8513   1
# 14 2018-12-02   6199   2
# 15 2018-12-03   6338   3
# 16 2018-12-04   4768   4
# 17 2018-12-05   9228   5
# 18 2018-12-06   9092   6
# 19 2018-12-07  10289   7
# 20 2018-12-08   7974   8
# 21 2018-12-09   6187   9
# 22 2018-12-10   7891  10
# 23 2018-12-11  10956  11
# 24 2018-12-12   5443  12
# 25 2018-12-13   9391  13
# 26 2018-12-14  10112  14
# 27 2018-12-15   9527  15
# 28 2018-12-16   5898  16
# 29 2018-12-17   4538  17
