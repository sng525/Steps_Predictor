# %%
import pandas as pd
path = r'C:\Users\olish\Documents\ml_projects\Steps_Predictor\model\src\components\artefacts\test.csv'
df = pd.read_csv(path)
df.head()
# Out:
#                                              type                 start_date  \
# 0               HKQuantityTypeIdentifierStepCount  2022-03-19 17:11:36 +0200
# 1  HKQuantityTypeIdentifierDistanceWalkingRunning  2022-05-19 19:54:53 +0200
# 2               HKQuantityTypeIdentifierStepCount  2022-04-22 15:00:41 +0200
# 3               HKQuantityTypeIdentifierStepCount  2021-01-28 13:26:47 +0200
# 4  HKQuantityTypeIdentifierDistanceWalkingRunning  2020-10-08 13:45:53 +0200
#
#        value
# 0    8.00000
# 1    0.04871
# 2   30.00000
# 3  129.00000
# 4    0.15383

# %%
unique_types = df['start_date'].apply(type).unique()
unique_types
# Out:
# array([<class 'str'>], dtype=object)

# %%
df.count()
# Out:
# type          32044
# start_date    32044
# value         32044
# dtype: int64

# %%
df.count()
# Out:
# type          128172
# start_date    128172
# value         128172
# dtype: int64

# %%
.8*x
# Out:
# np.float64(47362.4)

# %%
14691 + 32044
# Out:
# 46735
